# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Train Test and Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# ## Decision Tress

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %% [markdown]
# ## Prediction and Evaluation

# %%
predictions = dtree.predict(X_test)

# %%
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85297
#            1       0.78      0.75      0.76       146
#
#     accuracy                           1.00     85443
#    macro avg       0.89      0.87      0.88     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[85267    30]
#  [   37   109]]

# %%
from sklearn import tree
plt.figure(figsize=(20,25))
tree.plot_tree(dtree,feature_names=X.columns,class_names=['Class-1', 'Class-0'],rounded=True, # Rounded node edges
          filled=True, # Adds color according to class
          proportion=True
        )
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.over_sampling import SMOTE
import numpy as np
import time

# Load the dataset
df = pd.read_csv('creditcard.csv')

# Feature scaling: Scaling 'Amount' and 'Time'
scaler = StandardScaler()
df['scaled_amount'] = scaler.fit_transform(df['Amount'].values.reshape(-1, 1))
df['scaled_time'] = scaler.fit_transform(df['Time'].values.reshape(-1, 1))

# Drop the original columns after scaling
df = df.drop(['Amount', 'Time'], axis=1)

# Compute the correlation matrix
correlation_matrix = df.corr()

# Plot the enhanced correlation matrix with annotations
plt.figure(figsize=(15,10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix with Annotations')
plt.show()

# Define a threshold for selecting significant variables (correlation > 0.1)
significant_corr_threshold = 0.1
correlation_with_target = correlation_matrix['Class'].drop('Class')

# Identify significant features based on the threshold
significant_features = correlation_with_target[abs(correlation_with_target) > significant_corr_threshold].index.tolist()
insignificant_features = correlation_with_target[abs(correlation_with_target) <= significant_corr_threshold].index.tolist()

print("Significant Features (Correlation > 0.1):\n", significant_features)
print("\nRemoved Insignificant Features (Correlation <= 0.1):\n", insignificant_features)

# Keep only significant features
df_significant = df[significant_features + ['Class']]

# Define X (features) and y (target)
X = df_significant.drop('Class', axis=1)
y = df_significant['Class']

# Handle the imbalanced dataset using SMOTE
sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Measure training time
start_train_time = time.time()

# Train a Decision Tree model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

end_train_time = time.time()

# Measure prediction time for the test set
start_test_predict_time = time.time()

# Make predictions on the test set
y_pred = model.predict(X_test)

end_test_predict_time = time.time()

# Evaluate the model performance
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Calculate and print model accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%")

# Print training and prediction times
print(f"\nTraining Time: {end_train_time - start_train_time:.4f} seconds")
print(f"Prediction Time (for test set): {end_test_predict_time - start_test_predict_time:.4f} seconds")

# Now, let's predict for a new transaction

# Example new transaction data (replace with actual values)
new_data = pd.DataFrame({
    'Time': [10000],  # Replace with actual transaction time
    'V1': [-1.359807],  'V2': [-0.072781],  'V3': [2.536346], 'V4': [1.378155], 'V5': [-0.338321],
    'V6': [0.462388],  'V7': [0.239599],  'V8': [0.098698],  'V9': [0.363787],  'V10': [0.090794],
    'V11': [-0.5516],  'V12': [0.415798],  'V13': [-0.187257],  'V14': [0.069083],  'V15': [0.101288],
    'V16': [0.237609],  'V17': [-0.377869],  'V18': [0.505056],  'V19': [0.240543],  'V20': [0.252325],
    'V21': [-0.194401],  'V22': [0.261057],  'V23': [-0.143645],  'V24': [-0.206251],  'V25': [-0.190321],
    'V26': [0.159089],  'V27': [0.129697],  'V28': [-0.083082],
    'Amount': [123.45]  # Replace with actual transaction amount
})

# Feature scaling: Apply the same scaling as the training data
new_data['scaled_amount'] = scaler.transform(new_data['Amount'].values.reshape(-1, 1))
new_data['scaled_time'] = scaler.transform(new_data['Time'].values.reshape(-1, 1))

# Drop the original 'Amount' and 'Time' columns after scaling
new_data = new_data.drop(['Amount', 'Time'], axis=1)

# Select only the significant features for prediction
new_data_significant = new_data[significant_features]

# Measure prediction time for the new transaction
start_new_predict_time = time.time()

# Predict whether the new transaction is fraudulent
prediction = model.predict(new_data_significant)

end_new_predict_time = time.time()

# Interpret the prediction
if prediction[0] == 1:
    print("The transaction is fraudulent.")
else:
    print("The transaction is not fraudulent.")

# Print prediction time for the new transaction
print(f"Prediction Time (for new transaction): {end_new_predict_time - start_new_predict_time:.4f} seconds")
# Out:
# Significant Features (Correlation > 0.1):
#  ['V1', 'V3', 'V4', 'V7', 'V10', 'V11', 'V12', 'V14', 'V16', 'V17', 'V18']
#
# Removed Insignificant Features (Correlation <= 0.1):
#  ['V2', 'V5', 'V6', 'V8', 'V9', 'V13', 'V15', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'scaled_amount', 'scaled_time']
# Confusion Matrix:
#  [[56570   180]
#  [   74 56902]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56750
#            1       1.00      1.00      1.00     56976
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
#
# Model Accuracy: 99.78%
#
# Training Time: 21.8629 seconds
# Prediction Time (for test set): 0.0183 seconds
# The transaction is not fraudulent.
# Prediction Time (for new transaction): 0.0013 seconds

# %%
import time

# Non-fraudulent transaction example
new_data_non_fraudulent = pd.DataFrame({
    'V1': [-1.359807],  'V3': [2.536346], 'V4': [1.378155], 'V7': [0.239599],
    'V10': [0.090794], 'V11': [-0.5516],  'V12': [0.415798],  'V14': [0.069083],
    'V16': [0.237609],  'V17': [-0.377869],  'V18': [0.505056]
})

# Measure prediction time for non-fraudulent transaction
start_non_fraudulent_predict_time = time.time()

# Predict for non-fraudulent transaction
prediction_non_fraudulent = model.predict(new_data_non_fraudulent)

end_non_fraudulent_predict_time = time.time()

# Interpret the prediction and print response time
print("Non-Fraudulent Transaction Prediction: ", "Fraudulent" if prediction_non_fraudulent[0] == 1 else "Not Fraudulent")
print(f"Prediction Time (for non-fraudulent transaction): {end_non_fraudulent_predict_time - start_non_fraudulent_predict_time:.4f} seconds")


# Fraudulent transaction example
new_data_fraudulent = pd.DataFrame({
    'V1': [2.45],  'V3': [4.23], 'V4': [-5.20], 'V7': [-2.10],
    'V10': [-4.50], 'V11': [2.30],  'V12': [-3.45],  'V14': [-2.80],
    'V16': [3.15],  'V17': [-4.67],  'V18': [-1.67]
})

# Measure prediction time for fraudulent transaction
start_fraudulent_predict_time = time.time()

# Predict for fraudulent transaction
prediction_fraudulent = model.predict(new_data_fraudulent)

end_fraudulent_predict_time = time.time()

# Interpret the prediction and print response time
print("Fraudulent Transaction Prediction: ", "Fraudulent" if prediction_fraudulent[0] == 1 else "Not Fraudulent")
print(f"Prediction Time (for fraudulent transaction): {end_fraudulent_predict_time - start_fraudulent_predict_time:.4f} seconds")
# Out:
# Non-Fraudulent Transaction Prediction:  Not Fraudulent
# Prediction Time (for non-fraudulent transaction): 0.0016 seconds
# Fraudulent Transaction Prediction:  Fraudulent
# Prediction Time (for fraudulent transaction): 0.0017 seconds

# %%
import time
import pandas as pd

# Relevant features used during training
relevant_features = ['V1', 'V3', 'V4', 'V7', 'V10', 'V11', 'V12', 'V14', 'V16', 'V17', 'V18']

# Non-fraudulent transaction example (all features)
new_data_non_fraudulent = pd.DataFrame({
    'V1': [-1.359807],  'V2': [1.191857], 'V3': [2.536346], 'V4': [1.378155], 'V5': [-0.338321], 'V6': [0.462388],
    'V7': [0.239599], 'V8': [0.098697], 'V9': [0.363787], 'V10': [0.090794], 'V11': [-0.5516], 'V12': [0.415798],
    'V13': [0.212499], 'V14': [0.069083], 'V15': [0.121926], 'V16': [0.237609], 'V17': [-0.377869], 'V18': [0.505056],
    'V19': [0.108821], 'V20': [0.095896], 'V21': [-0.101342], 'V22': [-0.15302], 'V23': [0.335574], 'V24': [0.259221],
    'V25': [0.278891], 'V26': [0.403993], 'V27': [0.251412], 'V28': [0.112551]
})

# Fraudulent transaction example (all features)
new_data_fraudulent = pd.DataFrame({
    'V1': [2.45],  'V2': [-1.43], 'V3': [4.23], 'V4': [-5.20], 'V5': [3.29], 'V6': [-1.95],
    'V7': [-2.10], 'V8': [1.60], 'V9': [-2.87], 'V10': [-4.50], 'V11': [2.30], 'V12': [-3.45],
    'V13': [-2.56], 'V14': [-2.80], 'V15': [1.89], 'V16': [3.15], 'V17': [-4.67], 'V18': [-1.67],
    'V19': [2.55], 'V20': [-2.90], 'V21': [-1.75], 'V22': [1.32], 'V23': [-0.50], 'V24': [-2.10],
    'V25': [2.14], 'V26': [-1.30], 'V27': [-2.15], 'V28': [1.10]
})

# Measure prediction time using only relevant features (subset)
print("Predictions using relevant features:")

# Extract relevant features for non-fraudulent transaction
new_data_non_fraudulent_relevant = new_data_non_fraudulent[relevant_features]

# Measure prediction time for non-fraudulent transaction with relevant features
start_non_fraudulent_predict_time_relevant = time.time()
prediction_non_fraudulent_relevant = model.predict(new_data_non_fraudulent_relevant)
end_non_fraudulent_predict_time_relevant = time.time()

print("Non-Fraudulent Transaction Prediction (Relevant Features): ", "Fraudulent" if prediction_non_fraudulent_relevant[0] == 1 else "Not Fraudulent")
print(f"Prediction Time (Relevant Features): {end_non_fraudulent_predict_time_relevant - start_non_fraudulent_predict_time_relevant:.4f} seconds")

# Measure prediction time using all features (i.e., includes irrelevant ones too)
print("Predictions using all features (includes irrelevant ones):")

# Measure prediction time for non-fraudulent transaction with all features
start_non_fraudulent_predict_time_all = time.time()
# Selecting relevant features from the full dataset (this will mimic the overhead)
new_data_non_fraudulent_all = new_data_non_fraudulent[relevant_features]
prediction_non_fraudulent_all = model.predict(new_data_non_fraudulent_all)
end_non_fraudulent_predict_time_all = time.time()

print("Non-Fraudulent Transaction Prediction (All Features): ", "Fraudulent" if prediction_non_fraudulent_all[0] == 1 else "Not Fraudulent")
print(f"Prediction Time (All Features): {end_non_fraudulent_predict_time_all - start_non_fraudulent_predict_time_all:.4f} seconds")

# Fraudulent transaction (same procedure)
new_data_fraudulent_relevant = new_data_fraudulent[relevant_features]
start_fraudulent_predict_time_relevant = time.time()
prediction_fraudulent_relevant = model.predict(new_data_fraudulent_relevant)
end_fraudulent_predict_time_relevant = time.time()

print("Fraudulent Transaction Prediction (Relevant Features): ", "Fraudulent" if prediction_fraudulent_relevant[0] == 1 else "Not Fraudulent")
print(f"Prediction Time (Relevant Features): {end_fraudulent_predict_time_relevant - start_fraudulent_predict_time_relevant:.4f} seconds")

# Measure prediction time for fraudulent transaction with all features
start_fraudulent_predict_time_all = time.time()
# Selecting relevant features from the full dataset (this will mimic the overhead)
new_data_fraudulent_all = new_data_fraudulent[relevant_features]
prediction_fraudulent_all = model.predict(new_data_fraudulent_all)
end_fraudulent_predict_time_all = time.time()

print("Fraudulent Transaction Prediction (All Features): ", "Fraudulent" if prediction_fraudulent_all[0] == 1 else "Not Fraudulent")
print(f"Prediction Time (All Features): {end_fraudulent_predict_time_all - start_fraudulent_predict_time_all:.4f} seconds")
# Out:
# Predictions using relevant features:
# Non-Fraudulent Transaction Prediction (Relevant Features):  Not Fraudulent
# Prediction Time (Relevant Features): 0.0023 seconds
# Predictions using all features (includes irrelevant ones):
# Non-Fraudulent Transaction Prediction (All Features):  Not Fraudulent
# Prediction Time (All Features): 0.0029 seconds
# Fraudulent Transaction Prediction (Relevant Features):  Fraudulent
# Prediction Time (Relevant Features): 0.0022 seconds
# Fraudulent Transaction Prediction (All Features):  Fraudulent
# Prediction Time (All Features): 0.0149 seconds
